# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/Engr_Mujeeb Akbar/Downloads/heart_disease.csv')

# %%
data.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
data.shape
# Out:
# (10000, 21)

# %% [markdown]
# # Categorical:
# - Gender , Exercise Habits , Smoking , Family Heart Disease , Diabetes , High Blood Pressure , Low HDL Cholesterol , High LDL Cholesterol , Alcohol Consumption , Stress Level , Sugar Consumption ,
#
# # Numerical:
# - Age , Blood Pressure , Cholesterol Level , BMI , Sleep Hours , Triglyceride Level , Fasting Blood Sugar , CRP Level , Homocysteine Level
#
# # Target:
# - Heart Disease Status

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
data.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %%
data.isnull().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
data['Age'].isnull().sum()
# Out:
# 29

# %%
data['Age'].mean()
# Out:
# 49.29625915153946

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data.isnull().sum()
# Out:
# Age                        0
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      5003
# Female    4978
# Name: count, dtype: int64

# %%
4978+19
# Out:
# 4997

# %%
data['Gender'].dtype
# Out:
# dtype('O')

# %%
data['Gender'] = data['Gender'].fillna('Female')

# %%
data.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
data['Blood Pressure'].dtype
# Out:
# dtype('float64')

# %%
data['Blood Pressure'].mean()
# Out:
# 149.75773970544034

# %%
data['Blood Pressure'] = data['Blood Pressure'].fillna(149.7)

# %%
data['Cholesterol Level'].mean()
# Out:
# 225.42557673019058

# %%
data['Cholesterol Level'] = data['Cholesterol Level'].fillna(225.4)

# %%
data['Exercise Habits'].value_counts()
# Out:
# Exercise Habits
# High      3372
# Medium    3332
# Low       3271
# Name: count, dtype: int64

# %%
data['Exercise Habits'].isnull().sum()
# Out:
# 25

# %%
data['Exercise Habits'] = data['Exercise Habits'].bfill()

# %%
data['Exercise Habits'].isnull().sum()
# Out:
# 0

# %%
data[['Smoking' , 'Family Heart Disease' , 'Diabetes']].isnull().sum()
# Out:
# Smoking                 25
# Family Heart Disease    21
# Diabetes                30
# dtype: int64

# %%
data[['Smoking' , 'Family Heart Disease' , 'Diabetes']] = data[['Smoking' , 'Family Heart Disease' , 'Diabetes']].bfill()

# %%
data[['High Blood Pressure' , 'Low HDL Cholesterol' , 'High LDL Cholesterol',
      'Stress Level' , 'Sugar Consumption']].isnull().sum()
# Out:
# High Blood Pressure     26
# Low HDL Cholesterol     25
# High LDL Cholesterol    26
# Stress Level            22
# Sugar Consumption       30
# dtype: int64

# %%
data[['High Blood Pressure' , 'Low HDL Cholesterol' , 'High LDL Cholesterol',
      'Stress Level' , 'Sugar Consumption']] = data[['High Blood Pressure' , 'Low HDL Cholesterol' , 'High LDL Cholesterol',
      'Stress Level' , 'Sugar Consumption']].bfill()

# %%
data.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Blood Pressure             0
# Cholesterol Level          0
# Exercise Habits            0
# Smoking                    0
# Family Heart Disease       0
# Diabetes                   0
# BMI                       22
# High Blood Pressure        0
# Low HDL Cholesterol        0
# High LDL Cholesterol       0
# Alcohol Consumption     2586
# Stress Level               0
# Sleep Hours               25
# Sugar Consumption          0
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
data[['Alcohol Consumption' , 'Smoking']]
# Out:
#      Alcohol Consumption Smoking
# 0                   High     Yes
# 1                 Medium      No
# 2                    Low      No
# 3                    Low     Yes
# 4                    Low     Yes
# ...                  ...     ...
# 9995              Medium     Yes
# 9996                 NaN      No
# 9997                 NaN     Yes
# 9998              Medium     Yes
# 9999                High     Yes
#
# [10000 rows x 2 columns]

# %%
pd.get_dummies(data[['Alcohol Consumption' , 'Smoking']]).corr()
# Out:
#                             Alcohol Consumption_High  Alcohol Consumption_Low  \
# Alcohol Consumption_High                    1.000000                -0.325709
# Alcohol Consumption_Low                    -0.325709                 1.000000
# Alcohol Consumption_Medium                 -0.326755                -0.332267
# Smoking_No                                 -0.007924                -0.000536
# Smoking_Yes                                 0.007924                 0.000536
#
#                             Alcohol Consumption_Medium  Smoking_No  \
# Alcohol Consumption_High                     -0.326755   -0.007924
# Alcohol Consumption_Low                      -0.332267   -0.000536
# Alcohol Consumption_Medium                    1.000000    0.001848
# Smoking_No                                    0.001848    1.000000
# Smoking_Yes                                  -0.001848   -1.000000
#
#                             Smoking_Yes
# Alcohol Consumption_High       0.007924
# ...

# %%
# Check missing values
missing_percentage = data.isnull().mean() * 100
print(missing_percentage.sort_values(ascending=False))
# Out:
# Alcohol Consumption     25.86
# CRP Level                0.26
# Triglyceride Level       0.26
# Sleep Hours              0.25
# Fasting Blood Sugar      0.22
# BMI                      0.22
# Homocysteine Level       0.20
# Age                      0.00
# High LDL Cholesterol     0.00
# Sugar Consumption        0.00
# Stress Level             0.00
# Low HDL Cholesterol      0.00
# Gender                   0.00
# High Blood Pressure      0.00
# Diabetes                 0.00
# Family Heart Disease     0.00
# Smoking                  0.00
# Exercise Habits          0.00
# Cholesterol Level        0.00
# Blood Pressure           0.00
# Heart Disease Status     0.00
# dtype: float64

# %%
data = data.drop(['Alcohol Consumption'] , axis='columns')

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Stress Level', 'Sleep Hours', 'Sugar Consumption',
#        'Triglyceride Level', 'Fasting Blood Sugar', 'CRP Level',
#        'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Blood Pressure           0
# Cholesterol Level        0
# Exercise Habits          0
# Smoking                  0
# Family Heart Disease     0
# Diabetes                 0
# BMI                     22
# High Blood Pressure      0
# Low HDL Cholesterol      0
# High LDL Cholesterol     0
# Stress Level             0
# Sleep Hours             25
# Sugar Consumption        0
# Triglyceride Level      26
# Fasting Blood Sugar     22
# CRP Level               26
# Homocysteine Level      20
# Heart Disease Status     0
# dtype: int64

# %%
data[['BMI' , 'Sleep Hours' , 'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']].mean()
# Out:
# BMI                     29.077269
# Sleep Hours              6.991329
# Triglyceride Level     250.734409
# Fasting Blood Sugar    120.142213
# CRP Level                7.472201
# Homocysteine Level      12.456271
# dtype: float64

# %%
data[['BMI' , 'Sleep Hours' , 'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']].dtypes
# Out:
# BMI                    float64
# Sleep Hours            float64
# Triglyceride Level     float64
# Fasting Blood Sugar    float64
# CRP Level              float64
# Homocysteine Level     float64
# dtype: object

# %%
data[['BMI' , 'Sleep Hours' , 'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']] = data[['BMI' , 'Sleep Hours' , 'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']].fillna(data[['BMI' , 'Sleep Hours' , 'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']].mean())

# %%
data.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  \
# 0                  Yes       No  24.991591                 Yes
# 1                  Yes      Yes  25.221799                  No
# 2                   No       No  29.855447                  No
# 3                  Yes       No  24.130477                 Yes
# 4                  Yes      Yes  20.486289                 Yes
#
#   Low HDL Cholesterol High LDL Cholesterol Stress Level  Sleep Hours  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %% [markdown]
# # Now EDA

# %% [markdown]
# ## Step 1: Check Data Distribution

# %%
data.describe()
# Out:
#                 Age  Blood Pressure  Cholesterol Level           BMI  \
# count  10000.000000    10000.000000        10000.00000  10000.000000
# mean      49.296259      149.757630          225.42550     29.077269
# std       18.167567       17.556265           43.51039      6.300156
# min       18.000000      120.000000          150.00000     18.002837
# 25%       34.000000      134.000000          187.00000     23.668887
# 50%       49.000000      150.000000          225.40000     29.077269
# 75%       65.000000      165.000000          263.00000     34.509009
# max       80.000000      180.000000          300.00000     39.996954
#
#         Sleep Hours  Triglyceride Level  Fasting Blood Sugar     CRP Level  \
# count  10000.000000        10000.000000         10000.000000  10000.000000
# mean       6.991329          250.734409           120.142213      7.472201
# std        1.751002           86.953954            23.558052      4.334601
# ...

# %%
print(data['Gender'].value_counts())
print('***************************************')
print(data['Exercise Habits'].value_counts())
print('***************************************')
print(data['Smoking'].value_counts())
print('***************************************')
print(data['Family Heart Disease'].value_counts())
print('***************************************')
print(data['Diabetes'].value_counts())
print('***************************************')
print(data['High Blood Pressure'].value_counts())
print('***************************************')
print(data['Low HDL Cholesterol'].value_counts())
print('***************************************')
print(data['High LDL Cholesterol'].value_counts())
print('***************************************')
print(data['Stress Level'].value_counts())
print('***************************************')
print(data['Sugar Consumption'].value_counts())
# Out:
# Gender
# Male      5003
# Female    4997
# Name: count, dtype: int64
# ***************************************
# Exercise Habits
# High      3384
# Medium    3336
# Low       3280
# Name: count, dtype: int64
# ***************************************
# Smoking
# Yes    5132
# No     4868
# Name: count, dtype: int64
# ***************************************
# Family Heart Disease
# No     5013
# Yes    4987
# Name: count, dtype: int64
# ***************************************
# Diabetes
# No     5034
# Yes    4966
# Name: count, dtype: int64
# ***************************************
# High Blood Pressure
# Yes    5038
# No     4962
# Name: count, dtype: int64
# ***************************************
# Low HDL Cholesterol
# Yes    5011
# No     4989
# Name: count, dtype: int64
# ***************************************
# High LDL Cholesterol
# No     5047
# Yes    4953
# Name: count, dtype: int64
# ***************************************
# Stress Level
# Medium    3395
# Low       3326
# ...

# %% [markdown]
# ## Step 2: Visualizations

# %% [markdown]
# ### Univariate Analysis
# - Histograms & KDE Plots (for numerical features)

# %%
numerical_cols = ['Age' , 'Blood Pressure' , 'Cholesterol Level' , 'BMI' , 'Sleep Hours' ,
                  'Triglyceride Level' , 'Fasting Blood Sugar' , 'CRP Level' , 'Homocysteine Level']

for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(data[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# - Bar Plots (for categorical features)

# %%
categorical_cols = ['Gender' , 'Exercise Habits' , 'Smoking' , 'Family Heart Disease' ,
                    'Diabetes' , 'High Blood Pressure' , 'Low HDL Cholesterol' ,
                    'High LDL Cholesterol' , 'Stress Level' , 'Sugar Consumption']

for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(data=data, x=col, palette='coolwarm')
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# # OneHotEncoding for categorical values

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['Gender' , 'Exercise Habits' , 'Smoking' , 'Family Heart Disease' ,
                    'Diabetes' , 'High Blood Pressure' , 'Low HDL Cholesterol' ,
                    'High LDL Cholesterol' , 'Stress Level' , 'Sugar Consumption' , 'Heart Disease Status']

encoder = LabelEncoder()

for col in categorical_cols:
    data[col] = encoder.fit_transform(data[col])

# %%
data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  \
# 0     56.0       1           153.0              155.0                0
# 1     69.0       0           146.0              286.0                0
# 2     46.0       1           126.0              216.0                1
# 3     32.0       0           122.0              293.0                0
# 4     60.0       1           166.0              242.0                1
# ...    ...     ...             ...                ...              ...
# 9995  25.0       0           136.0              243.0                2
# 9996  38.0       1           172.0              154.0                2
# 9997  73.0       1           152.0              201.0                0
# 9998  23.0       1           142.0              299.0                1
# 9999  38.0       0           128.0              193.0                2
#
#       Smoking  Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# ...

# %% [markdown]
# ## Bivariate Analysis (Feature vs Target)
# - Checking correlation of features with Heart Disease

# %%
correlation = data.corr()
plt.figure(figsize=(20, 12))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# ## Boxplot for Numerical Features (Outliers Detection)

# %%
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=data, x="Heart Disease Status", y=col, palette="coolwarm")
    plt.title(f"{col} vs Heart Disease")
    plt.show()

# %% [markdown]
# ## Smoking vs. Heart Disease

# %%
sns.countplot(data=data, x='Smoking', hue='Heart Disease Status', palette='coolwarm')
plt.title("Smoking vs. Heart Disease")
plt.show()

# %% [markdown]
# Means that Smoking is not effecting the Heart Disease

# %% [markdown]
# ## Feature Importance (Select Best Features)
# - If you're using a tree-based model, check feature importance:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X = data.drop(columns=['Heart Disease Status'])
y = data['Heart Disease Status']

# %%
model = RandomForestClassifier(n_estimators=200)
model.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance, palette="coolwarm")
plt.title("Feature Importance for Heart Disease Prediction")
plt.show()

# %% [markdown]
# it showed me the most important features

# %% [markdown]
# ## Checking Class Imbalance
# - Check if Heart Disease Status is balanced:

# %%
sns.countplot(x=data['Heart Disease Status'])
plt.title("Class Distribution of Target Variable")
plt.show()

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.2)

# %%
data.head(1)
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  Smoking  \
# 0  56.0       1           153.0              155.0                0        1
#
#    Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# 0                     1         0  24.991591                    1
#
#    Low HDL Cholesterol  High LDL Cholesterol  Stress Level  Sleep Hours  \
# 0                    1                     0             2     7.633228
#
#    Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0                  2               342.0           120.142213  12.969246
#
#    Homocysteine Level  Heart Disease Status
# 0            12.38725                     0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression


# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Feature Selection (Selecting 5 best features)
selector = SelectKBest(score_func=f_classif, k=5)
X_selected = selector.fit_transform(X_scaled, y)

# Cross-validation using Logistic Regression
log_reg = LogisticRegression()
cv_scores = cross_val_score(log_reg, X_selected, y, cv=5)  # 5-fold CV

# Training the final model
log_reg.fit(X_selected, y)

# Display Cross-Validation results
print(f"Mean CV Score: {cv_scores.mean():.4f}, Standard Deviation: {cv_scores.std():.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 13
#      11 # Feature Selection (Selecting 5 best features)
#      12 selector = SelectKBest(score_func=f_classif, k=5)
# ---> 13 X_selected = selector.fit_transform(X_scaled, y)
#      15 # Cross-validation using Logistic Regression
#      16 log_reg = LogisticRegression()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Load dataset
df = pd.read_csv('C:/Users/Engr_Mujeeb Akbar/Downloads/heart_disease.csv')

# Extract features (X) and target (y)
target_column = 'target'  # Ensure this matches the actual target variable
X = df.drop(columns=[target_column])
y = df[target_column]

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Feature Selection (Selecting 5 best features)
selector = SelectKBest(score_func=f_classif, k=5)
X_selected = selector.fit_transform(X_scaled, y)

# Cross-validation using Logistic Regression
log_reg = LogisticRegression()
cv_scores = cross_val_score(log_reg, X_selected, y, cv=5)  # 5-fold CV

# Training the final model
log_reg.fit(X_selected, y)

# Display Cross-Validation results
print(f"Mean CV Score: {cv_scores.mean():.4f}, Standard Deviation: {cv_scores.std():.4f}")

# %%
lr.fit(X_train , y_train)

# %%
svc.fit(X_train , y_train)

# %%
rfc.fit(X_train , y_train)

# %%
gnb.fit(X_train , y_train)

# %%
tree.fit(X_train , y_train)

# %%
print("Logestic Regression: " , lr.score(X_test , y_test) * 100)
print("SCV: " , svc.score(X_test , y_test) * 100)
print("Random Forest Classifier: " , rfc.score(X_test , y_test) * 100)
print("Gaussian NB: " , gnb.score(X_test , y_test) * 100)
print("Decision Tree Classifier: " , tree.score(X_test , y_test) * 100)

# %% [markdown]
# ## Hyperparameter Tuning
# - Try GridSearchCV to fine-tune models.

# %% [markdown]
# ### For SVC

# %%
from sklearn.model_selection import GridSearchCV

# %%
# param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf', 'poly']}
# grid = GridSearchCV(SVC(), param_grid, cv=5)
# grid.fit(X_train, y_train)

# %%
# print("Best SVC Parameters:", grid.best_params_)
# print("Best SVC Score:", grid.best_score_)

# %% [markdown]
# ### For Random Forest

# %%
# param_grid = {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20]}
# grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
# grid.fit(X_train, y_train)

# %%
# print("Best Random Forest Parameters:", grid.best_params_)
# print("Best Random Forest Score:", grid.best_score_)

# %% [markdown]
# ## Ensemble Model

# %%
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Load dataset
df = pd.read_csv('C:/Users/Engr_Mujeeb Akbar/Downloads/heart_disease.csv')

# Extract features (X) and target (y)
target_column = 'target'  # Ensure this matches the actual target variable
X = df.drop(columns=[target_column])
y = df[target_column]

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Feature Selection (Selecting 5 best features)
selector = SelectKBest(score_func=f_classif, k=5)
X_selected = selector.fit_transform(X_scaled, y)

# Cross-validation using Logistic Regression
log_reg = LogisticRegression()
cv_scores = cross_val_score(log_reg, X_selected, y, cv=5)  # 5-fold CV

# Training the final model
log_reg.fit(X_selected, y)

# Display Cross-Validation results
print(f"Mean CV Score: {cv_scores.mean():.4f}, Standard Deviation: {cv_scores.std():.4f}")

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score , confusion_matrix , classification_report

# %%
mean_absolute_error(y_test , y_pred)
# Out:
# 0.2035

# %%
mean_squared_error(y_test , y_pred)
# Out:
# 0.2035

# %%
r2_score(y_test , y_pred)
# Out:
# -0.25549278091650973

# %%
cm = confusion_matrix(y_test , y_pred)
cm
# Out:
# array([[1593,    0],
#        [ 407,    0]], dtype=int64)

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1593
#            1       0.00      0.00      0.00       407
#
#     accuracy                           0.80      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.63      0.80      0.71      2000
# C:\Users\Engr_Mujeeb Akbar\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Engr_Mujeeb Akbar\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
sns.heatmap(cm , annot=True)
# Out:
# <Axes: >

# %%
lr.predict([[52 , 1 , 190 , 130 , 0 , 0 , 1 , 0 , 244 , 0 , 0 , 0 , 1 , 8 , 2 , 500 , 190 , 11 , 10]])
# Out:
# C:\Users\Engr_Mujeeb Akbar\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
X.head(1)
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  Smoking  \
# 0  56.0       1           153.0              155.0                0        1
#
#    Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# 0                     1         0  24.991591                    1
#
#    Low HDL Cholesterol  High LDL Cholesterol  Stress Level  Sleep Hours  \
# 0                    1                     0             2     7.633228
#
#    Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0                  2               342.0           120.142213  12.969246
#
#    Homocysteine Level
# 0            12.38725

# %%
X.head(1)
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  Smoking  \
# 0  56.0       1           153.0              155.0                0        1
#
#    Family Heart Disease  Diabetes        BMI  High Blood Pressure  \
# 0                     1         0  24.991591                    1
#
#    Low HDL Cholesterol  High LDL Cholesterol  Stress Level  Sleep Hours  \
# 0                    1                     0             2     7.633228
#
#    Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0                  2               342.0           120.142213  12.969246
#
#    Homocysteine Level
# 0            12.38725

# %%
from sklearn.model_selection import StratifiedKFold

# %%
fold = StratifiedKFold(n_splits=5)

# %%
for train_index , test_index in fold.split(X , y):
    print(train_index , test_index)
# Out:
# [1600 1601 1602 ... 9997 9998 9999] [   0    1    2 ... 8397 8398 8399]
# [   0    1    2 ... 9997 9998 9999] [1600 1601 1602 ... 8797 8798 8799]
# [   0    1    2 ... 9997 9998 9999] [3200 3201 3202 ... 9197 9198 9199]
# [   0    1    2 ... 9997 9998 9999] [4800 4801 4802 ... 9597 9598 9599]
# [   0    1    2 ... 9597 9598 9599] [6400 6401 6402 ... 9997 9998 9999]

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# Load dataset
df = pd.read_csv('C:/Users/Engr_Mujeeb Akbar/Downloads/heart_disease.csv')

# Extract features (X) and target (y)
target_column = 'target'  # Ensure this matches the actual target variable
X = df.drop(columns=[target_column])
y = df[target_column]

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Feature Selection (Selecting 5 best features)
selector = SelectKBest(score_func=f_classif, k=5)
X_selected = selector.fit_transform(X_scaled, y)

# Cross-validation using Logistic Regression
log_reg = LogisticRegression()
cv_scores = cross_val_score(log_reg, X_selected, y, cv=5)  # 5-fold CV

# Training the final model
log_reg.fit(X_selected, y)

# Display Cross-Validation results
print(f"Mean CV Score: {cv_scores.mean():.4f}, Standard Deviation: {cv_scores.std():.4f}")
# Out:
# C:\Users\Engr_Mujeeb Akbar\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Engr_Mujeeb Akbar\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
cross_val_score(SVC(kernel='rbf') , X , y)
# Out:
# array([0.8, 0.8, 0.8, 0.8, 0.8])

# %%
cross_val_score(RandomForestClassifier(n_estimators=200) , X , y)
# Out:
# array([0.8, 0.8, 0.8, 0.8, 0.8])

# %%
cross_val_score(GaussianNB() , X , y)
# Out:
# array([0.8, 0.8, 0.8, 0.8, 0.8])

# %%
cross_val_score(DecisionTreeClassifier(max_depth=100) , X , y)
# Out:
# array([0.6635, 0.658 , 0.689 , 0.66  , 0.674 ])
